# %% [markdown]
# **# A good Title
# # Description of the task
# # Your name in some color
# # Bring our Team photo from the given url "https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg"
# # Use headings, bold, italics appropriately.**

# %% [markdown]
# # _Data Engineering_
# ## Practice
# ### Dinesh
# ![](https://kingnewswire.com/wp-content/uploads/data-engineering-and-its-importance-in-todays-world-1723108448.png)

# %% [markdown]
# # **Task2: Create a volume namely usage_metrics using sql magic command %sql**

# %%
# %sql

CREATE VOLUME IF NOT EXISTS workspace.default.volume;

# %%
# %py
dbutils.fs.cp("/Volumes/workspace/default/volume/mobile_os_usage1.csv","/Volumes/workspace/default/volume/mobile_os_usage4.csv", True)

# %% [markdown]
# **Task3:
# Create a child notebook "4_child_nb_dataload" and write code to load data, Using the requests library, perform api call to pull data from "https://public.tableau.com/app/sample-data/mobile_os_usage.csv" into a python variable using the magic command %py and write the data into the created volume "/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv" using the above variable.text using the magic command dbutils.fs.put("volume",variable.text,overwrite=True)**

# %%
# %py
import requests 
file = requests.get("https://public.tableau.com/app/sample-data/mobile_os_usage.csv")  
dbutils.fs.put("/Volumes/workspace/default/volume/mobile_os_usage1.csv", file.text,True)

# %% [markdown]
# Task4: Call the notebook 4_child_nb_dataload using the magic command %run

# %%
# %run("/Workspace/Users/dineshdhina300@gmail.com/Databricks-2025-/Practice_notebooks/Prac_DB/")

# %%
# %sh
ls /Workspace

# %%
# %python
df1=spark.read.csv("/Volumes/workspace/default/volume/mobile_os_usage1.csv")
display(df1)

# %%
# %py
df1=spark.read.csv("/Volumes/workspace/default/volume/mobile_os_usage1.csv")
df1.write.saveAsTable("default.Sampdata_TB4")
display(df1)

# %%
# %sql
select * from default.Sampdata_TB4;

# %%
# %py
up = 'Dinesh Inceptez'
print(up.upper())

# %%
# %pip install pypi

# %%
# %py 
import pandas
display(pandas.read_csv("/Volumes/workspace/default/volume/mobile_os_usage1.csv"))

# %%
# %sh
echo "Magic commands tasks completed"
