# %%
# %sql

CREATE catalog IF NOT EXISTS telecom_catalog_assign;
CREATE schema IF NOT EXISTS telecom_catalog_assign.landing_zone;
CREATE VOLUME IF NOT EXISTS telecom_catalog_assign.landing_zone.landing_vol;

# %%
dbutils.fs.mkdirs("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/customer/")
dbutils.fs.mkdirs("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/usage/")
dbutils.fs.mkdirs("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/tower/")

# %%
customer_csv = '''
101,Arun,31,Chennai,PREPAID
102,Meera,45,Bangalore,POSTPAID
103,Irfan,29,Hyderabad,PREPAID
104,Raj,52,Mumbai,POSTPAID
105,,27,Delhi,PREPAID
106,Sneha,abc,Pune,PREPAID
'''
usage_tsv = '''customer_id\tvoice_mins\tdata_mb\tsms_count
101\t320\t1500\t20
102\t120\t4000\t5
103\t540\t600\t52
104\t45\t200\t2
105\t0\t0\t0
'''
tower_logs_region1 = '''event_id|customer_id|tower_id|signal_strength|timestamp
5001|101|TWR01|-80|2025-01-10 10:21:54
5004|104|TWR05|-75|2025-01-10 11:01:12
'''
file_name="/Volumes/telecom_catalog_assign/landing_zone/landing_vol/customer/customer.csv"
file_name1="/Volumes/telecom_catalog_assign/landing_zone/landing_vol/usage/usage.tsv"
file_name2="/Volumes/telecom_catalog_assign/landing_zone/landing_vol/tower/tower_logs_region1.csv"

dbutils.fs.put(file_name,customer_csv,True)
print("success copied to customer_csv")
dbutils.fs.put(file_name1,usage_tsv,True)
print("success copied to usage_tsv")
dbutils.fs.put(file_name2,tower_logs_region1,True)
print("success copied to tower_logs_region1")

# %%
df = spark.read.option("header", True).option("pathGlobFilter", "*.csv").csv("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/customer/customer.csv")
