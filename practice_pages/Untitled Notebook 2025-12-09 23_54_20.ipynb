# %%
# %sql
CREATE VOLUME IF NOT EXISTS usage_metrics;

# %%
# %py
dbutils.fs.cp("/Volumes/workspace/default/volume/mobile_os_usage1.csv","/Volumes/workspace/default/volume/mobile_os_usage5.csv", True)
